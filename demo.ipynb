# %%
from tensorflow.keras.models import load_model
model=load_model("D:\Multi_disease_app\backend\models\pneumonia.keras")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\hp\AppData\Local\Temp\ipykernel_3988\1824958227.py:2: SyntaxWarning: invalid escape sequence '\M'
#   model=load_model("D:\Multi_disease_app\backend\models\pneumonia.keras")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from tensorflow.keras.models import load_model
#       2 model=load_model("D:\Multi_disease_app\backend\models\pneumonia.keras")
#
# ModuleNotFoundError: No module named 'tensorflow'
